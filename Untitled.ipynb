# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]

plt.show()

# %%
plt.plot([],[])
plt.xlabel('neuron_num')
plt.ylabel('AUC_mean')

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-10, 10, 11)
X = np.tile(x, (11, 1))
Y = np.transpose(X)
Z = 2 * np.random.rand(11, 11) - 1

surf = ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_zlim(-5, 5)
ax.set_xticks([-10, -5, 0, 5, 10])
ax.set_yticks([-10, -5, 0, 5, 10])
ax.set_zticks([-5, 0, 5])

fig.colorbar(surf, shrink=0.6, aspect=8)
surf.set_clim(-1.0, 1.0)
plt.tight_layout()
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-10, 10, 11)
X = np.tile(x, (11, 1))
Y = np.transpose(X)
Z = 2 * np.random.rand(11, 11) - 1

X = (5, 10, 20, 30)
Y = (0.10, 0.30, 0.50, 1.00)

surf = ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_zlim(0.860, 0.935)
ax.set_xticks([5, 10, 20, 30])
ax.set_yticks([0.10, 0.30, 0.50, 1.00])
ax.set_zticks([0.860, 0.875, 0.890, 0.905, 0.920, 0.935])

fig.colorbar(surf, shrink=0.6, aspect=8)
surf.set_clim(0.860, 0.935)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/fs/h7y9dtqn1fz159fcvcpwkzhh0000gp/T/ipykernel_2634/616139018.py in <module>
#      15 Y = (0.10, 0.30, 0.50, 1.00)
#      16
# ---> 17 surf = ax.plot_surface(X, Y, Z, cmap='viridis')
#      18 ax.set_zlim(0.860, 0.935)
#      19 ax.set_xticks([5, 10, 20, 30])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1663
#    1664         # TODO: Support masked arrays
# ...

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-10, 10, 11)
X = np.tile(x, (11, 1))
Y = np.transpose(X)
Z = np.random.rand(11, 11)

ax.plot_surface(X, Y, Z)
ax.set_zlim(-10, 10)

plt.tight_layout()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)

X = (5, 10, 20, 30)
Y = (0.10, 0.30, 0.50, 1.00)

XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(XX, YY, ZZ, rstride=1, cstride=1, cmap='hot')
plt.show()
# Out:
# /var/folders/fs/h7y9dtqn1fz159fcvcpwkzhh0000gp/T/ipykernel_2634/1725323092.py:13: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
x=[1:0.1:3];
y=[1:0.1:5];
[X Y]=meshgrid(x,y);
Z=X.^2+Y.^2;
mesh(X,Y,Z)
# Out:
#   File "/var/folders/fs/h7y9dtqn1fz159fcvcpwkzhh0000gp/T/ipykernel_2634/2899747442.py", line 1
#     x=[1:0.1:3];
#         ^
# SyntaxError: invalid syntax
